# %% [markdown]
# # Viewing Metric History
# This notebook is designed to view the current metric history separately, in a read only state. Simply run the below cells, and it will generate a viewable panda dataframe.

# %%
import numpy as np
# import pandas. optional but helpful 'display.max_columns' arg shows all DataFrame columns when printing
print('importing pandas')
import pandas
from pandas import DataFrame
import pickle   #to load in metrics history
pandas.set_option('display.max_columns', None)
# Out:
# importing pandas

# %%
filename = 'weekly_metric_history_DO_NOT_DELETE.pkl'
# Read dictionary pkl file
with open(filename, 'rb') as fp:
    metrics_history = pickle.load(fp)
metrics_df = DataFrame.from_dict(metrics_history,orient='index',)
metrics_df
# Out:
#                                   0             1             2             3  \
# duration               2.677208e+13  6.360590e+12  1.111197e+13  1.364830e+13
# rchar                  2.864193e+15  7.492875e+14  1.379381e+15  1.588450e+15
# syscr                  1.572196e+11  4.645771e+10  8.687558e+10  9.647779e+10
# syscw                  6.994664e+10  2.106678e+10  3.890883e+10  4.334137e+10
# wchar                  2.022362e+15  5.399566e+14  9.923022e+14  1.131634e+15
# cstime                 1.247814e+13  3.161840e+12  5.738674e+12  6.952267e+12
# cutime                 1.504913e+13  3.917596e+12  7.022879e+12  9.091559e+12
# majflt                 2.244518e+08  5.843880e+07  7.896526e+07  9.215410e+07
# cpu_time               1.304595e+13  3.412335e+12  6.122069e+12  7.307443e+12
# minflt                 6.177803e+11  1.734823e+11  2.983079e+11  3.498852e+11
# rssmax                 7.673445e+12  1.912197e+12  3.159945e+12  4.863460e+12
# ...

# %%
filename = 'weekly_node_flow_history_DO_NOT_DELETE.pkl'
# Read dictionary pkl file
with open(filename, 'rb') as fp:
    metrics_history = pickle.load(fp)
metrics_df = DataFrame.from_dict(metrics_history,orient='index',)
pandas.set_option('display.max_rows', None)
pandas.set_option('display.max_columns', None)
metrics_df
# Out:
#              0         1         2         3         4         5         6  \
# 016    138.841    127.29   127.334   124.858   121.885   121.223   146.873
# 027    156.252   184.046   183.001   185.678   184.739   186.812   168.296
# 028    156.562   181.592   170.962   181.281   187.338   182.949   160.542
# 029    140.478   175.972    164.36   172.655   172.503   172.597    150.99
# 030    138.113   163.861   177.779   173.812   174.108   179.367   206.669
# 031    145.053   182.899   185.822   192.809   197.886   195.575   164.793
# 032    150.338   167.647   183.002   187.685   197.154   186.878   164.062
# 033     154.05   169.972   175.785   182.109     179.2   172.386   146.791
# 034    229.364   232.714   259.894   256.258   257.671   242.251   205.732
# 035    149.714   163.548   174.483   172.077    171.66   162.542   147.868
# 037    137.215   157.768   178.098   181.475   177.327    178.85   149.167
# ...

# %%
numbers = [
    188.646, 212.017, 241.943, 243.197, 249.702, 238.22, 209.114, 181.752, 167.131, 177.065, 171.587,
    166.285, 175.292, 182.991, 189.265, 180.601, 101.42, 155.184, 154.647, 159.912, 160.254, 157.353,
    157.761, 148.372, 150.785, 152.101, 148.624, 148.089, 146.113, 147.732, 156.743, 160.309, 155.754,
    160.07, 149.137, 142.907, 143.66, 144.573, 154.479, 124.64, 119.806, 120.484, 156.067, 213.314,
    214.033, 209.041, 210.072, 223.033, 210.911, 207.246, 223.901, 230.856, 240.816, 249.704, 257.842,
    284.235, 262.346, 268.183, 281.537, 270.695
]

# Calculate the average and standard error
mean = np.mean(numbers)
stderr = np.std(numbers, ddof=1) / np.sqrt(len(numbers))

print("Average:", mean)
print("Standard Error:", stderr)

# %%
df = {
    "frequency":{
        "1hr":"sampled hourly",
        "1hrCM":"monthly-mean diurnal cycle resolving each day into 1-hour means",
        "1hrPt":"sampled hourly, at specified time point within an hour",
        "3hr":"3 hourly mean samples",
        "3hrPt":"sampled 3 hourly, at specified time point within the time period",
        "6hr":"6 hourly mean samples",
        "6hrPt":"sampled 6 hourly, at specified time point within the time period",
        "day":"daily mean samples",
        "dec":"decadal mean samples",
        "fx":"fixed (time invariant) field",
        "mon":"monthly mean samples",
        "monC":"monthly climatology computed from monthly mean samples",
        "monPt":"sampled monthly, at specified time point within the time period",
        "subhrPt":"sampled sub-hourly, at specified time point within an hour",
        "yr":"annual mean samples",
        "yrPt":"sampled yearly, at specified time point within the time period"
    },
    "version_metadata":{
        "CV_collection_modified":"Fri Apr 18 16:28:35 2025 -0700",
        "CV_collection_version":"6.2.58.79",
        "author":"Paul J. Durack <durack1@llnl.gov>",
        "frequency_CV_modified":"Mon May 24 13:48:15 2021 00100",
        "frequency_CV_note":"Update description of 3hr and 6hr frequencies",
        "institution_id":"PCMDI",
        "previous_commit":"1e8961cb140d3246c70cdc24d2cc8404570de5dc",
        "specs_doc":"v6.2.7 (10th September 2018; https://goo.gl/v1drZl)"
    }
}
# Out:
#   File "<ipython-input-20-cef67208142c>", line 2
#     "frequency":{
#                ^
# SyntaxError: invalid syntax

# %%
pandas_df = DataFrame.from_dict(df,orient='index')

# %%
pandas_df['frequency']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/fms/local/epmt/4.9.2-centos-7/epmt-install/epmt/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'frequency'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-ca22fcd3bcf1> in <module>
# ----> 1 pandas_df['frequency']
#
# /home/fms/local/epmt/4.9.2-centos-7/epmt-install/epmt/pandas/core/frame.pyc in __getitem__(self, key)
#
# ...

# %%
df.keys()
# Out:
# dict_keys(['frequency', 'version_metadata'])

# %%
metrics_df[0]
# Out:
# duration                 2.677208e+13
# rchar                    2.864193e+15
# syscr                    1.572196e+11
# syscw                    6.994664e+10
# wchar                    2.022362e+15
# cstime                   1.247814e+13
# cutime                   1.504913e+13
# majflt                   2.244518e+08
# cpu_time                 1.304595e+13
# minflt                   6.177803e+11
# rssmax                   7.673445e+12
# cmajflt                  3.823432e+08
# cminflt                  1.365617e+12
# usertime                 8.235630e+12
# num_procs                1.690061e+08
# vol_ctxsw                3.278371e+10
# read_bytes               1.594669e+15
# systemtime               4.810315e+12
# time_oncpu               1.304905e+16
# timeslices               3.578136e+10
# invol_ctxsw              2.812938e+09
# write_bytes              1.741072e+15
# time_waiting             4.505098e+14
# cancelled_write_bytes    5.945467e+13
# jobs                     2.169900e+04
# ...
